# %%
from Bio import Entrez
import pandas as pd
import numpy as np
import random


# get list of IDs of studies that match your query
def search(query):
    Entrez.email = 'vdp14@case.edu'
    handle = Entrez.esearch(db='pubmed', sort='relevance', retmax='250000', retmode='xml', term=query)
    results = Entrez.read(handle)
    return results

# search for cardiac tissue engineering papers
q = 'decellularized ECM for cardiac tissue engineering'
studies = search(q)
studiesIdList = studies['IdList']
print(len(studiesIdList))

# If you want to reduce the number of papers for easy computation
# studiesIdList_shortened = random.sample(studiesIdList, 300)


# Use efetch to get the details of each study
def fetch_details(id_list):
    ids = ','.join(id_list)
    Entrez.email = 'vdp14@case.edu'
    handle = Entrez.efetch(db='pubmed', retmode='xml', id=ids)
    results = Entrez.read(handle)
    return results

# create a pandas df that has the pubmed article info (title, abstract, journal, date, etc.)
# Efetch runs 10,000 studies max, so separate idList in sections
titles = []
abstracts = []
journals = []
pubdate_years = []
pudate_months = []

studies = fetch_details(studiesIdList)
chuncks_size = 10000

'''
Challenge:
Not all full text articles are available so we will have to write a function that retrieves free full text articles. There will probably be another list that has texts
that were not able to be retrieve that we will then feed PDFs to. The function will break down the PDF into similar format as the .xml files for consistency.
'''

# URL to retrieve publically available articles
format = 'json'
id = studiesIdList
url_bioc = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_[format]/[ID]/[encoding]'
# Out:
# 387

# %%
format = 'json'
id = studiesIdList[:10]
encoding = 'ascii'
# url_bioc = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_' + format + '/' + id + '/' + encoding
# print(url_bioc)

# %%
import urllib.request, json

# %%
for i in id:
    print(i)
    try:
        url_bioc = 'https://www.ncbi.nlm.nih.gov/research/bionlp/RESTful/pmcoa.cgi/BioC_' + format + '/' + i + '/' + encoding
        response = urllib.request.urlopen(url_bioc)
        data = json.loads(response.read())
    except:
        print('No open access file for ', i)
# Out:
# 34901526
# 31075518
# No open access file for  31075518
# 36361824
# 26119160
# No open access file for  26119160
# 35960635
# No open access file for  35960635
# 32601935
# No open access file for  32601935
# 35360395
# 31271596
# 37406920
# No open access file for  37406920
# 32279344
# No open access file for  32279344

# %%
studies_table = pd.DataFrame()
keys = data.keys()
keys
# for x in data['source']:
#     keys = x.keys()
#     print(keys)
# Out:
# dict_keys(['source', 'date', 'key', 'infons', 'documents'])

# %%
main_content = data['documents'][0]['passages']
main_content
# Out:
# [{'offset': 0,
#   'infons': {'article-id_doi': '10.1016/j.bioactmat.2021.09.014',
#    'article-id_pii': 'S2452-199X(21)00431-X',
#    'article-id_pmc': '8637010',
#    'article-id_pmid': '34901526',
#    'fpage': '15',
#    'kwd': 'Decellularization ECM 3D scaffolds Tissue regeneration Recellularization',
#    'license': 'This is an open access article under the CC BY-NC-ND license (http://creativecommons.org/licenses/by-nc-nd/4.0/).',
#    'lpage': '31',
#    'name_0': 'surname:Zhang;given-names:Xuewei',
#    'name_1': 'surname:Chen;given-names:Xi',
#    'name_2': 'surname:Hong;given-names:Hua',
#    'name_3': 'surname:Hu;given-names:Rubei',
#    'name_4': 'surname:Liu;given-names:Jiashang',
#    'name_5': 'surname:Liu;given-names:Changsheng',
#    'section_type': 'TITLE',
#    'title': 'Keywords',
#    'type': 'front',
#    'volume': '10',
#    'year': '2021'},
#   'text': 'Decellularized extracellular matrix scaffolds: Recent trends and emerging strategies in tissue engineering',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 107,
#   'infons': {'section_type': 'ABSTRACT', 'type': 'abstract'},
#   'text': 'The application of scaffolding materials is believed to hold enormous potential for tissue regeneration. Despite the widespread application and rapid advance of several tissue-engineered scaffolds such as natural and synthetic polymer-based scaffolds, they have limited repair capacity due to the difficulties in overcoming the immunogenicity, simulating in-vivo microenvironment, and performing mechanical or biochemical properties similar to native organs/tissues. Fortunately, the emergence of decellularized extracellular matrix (dECM) scaffolds provides an attractive way to overcome these hurdles, which mimic an optimal non-immune environment with native three-dimensional structures and various bioactive components. The consequent cell-seeded construct based on dECM scaffolds, especially stem cell-recellularized construct, is considered an ideal choice for regenerating functional organs/tissues. Herein, we review recent developments in dECM scaffolds and put forward perspectives accordingly, with particular focus on the concept and fabrication of decellularized scaffolds, as well as the application of decellularized scaffolds and their combinations with stem cells (recellularized scaffolds) in tissue engineering, including skin, bone, nerve, heart, along with lung, liver and kidney.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1410,
#   'infons': {'section_type': 'ABSTRACT', 'type': 'abstract_title_1'},
#   'text': 'Graphical abstract',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1429,
#   'infons': {'section_type': 'ABSTRACT', 'type': 'abstract_title_1'},
#   'text': 'Highlight',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1439,
#   'infons': {'section_type': 'ABSTRACT', 'type': 'abstract'},
#   'text': 'dECM scaffolds for tissue regeneration are primarily introduced according to the development and fabrication of decellularized scaffolds, as well as the application of dECM scaffolds and their constructs combined with stem cells in various tissue engineering.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1699,
#   'infons': {'section_type': 'ABSTRACT', 'type': 'abstract'},
#   'text': 'Limitations, challenges, and perspectives of dECM for accelerating development of tissue regeneration are discussed, respectively.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1830,
#   'infons': {'section_type': 'INTRO', 'type': 'title_1'},
#   'text': 'Introduction of decellularized extracellular matrix scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1892,
#   'infons': {'file': 'tbl1.xml',
#    'id': 'tbl1',
#    'section_type': 'TABLE',
#    'type': 'table_caption'},
#   'text': 'List of main protein components in dECM.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1933,
#   'infons': {'file': 'tbl1.xml',
#    'id': 'tbl1',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th>Protein</th><th>Distributions</th><th>Function</th><th>Reference</th></tr></thead><tbody><tr><td align="left"><bold>Collagen</bold></td><td align="left">The skeletal systems and most soft tissues</td><td align="left">Provide tensile strength, connect the framework of tissue/organ, affect cell types disposition</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib9" ref-type="bibr">9</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Elastin</bold></td><td align="left">Most soft tissues, such as vasculature and muscle</td><td align="left">Provide elasticity, adjust mechanical properties, increase hemocompatibility</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib9" ref-type="bibr">9</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Fibronectin</bold></td><td align="left">Most organs/tissues</td><td align="left">Regulate cell behavior and function, guide branching morphogenesis in the development of complicated structures</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib8" ref-type="bibr">8</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Laminin</bold></td><td align="left">Cartilage, muscle</td><td align="left">Promote cell adhesion and migration, provide bioactive sites for cross-linking</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib8" ref-type="bibr">8</xref></td></tr><tr><td align="left"><bold>Matricellular Proteins</bold></td><td align="left">Vasculature</td><td align="left">Contain binding sites for ECM structural proteins and cell surface receptors, and modulate activities of specific growth factors</td><td align="left"><xref rid="bib9" ref-type="bibr">9</xref></td></tr></tbody></table>\n'},
#   'text': 'Table 1\t \t',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 1944,
#   'infons': {'file': 'tbl1.xml',
#    'id': 'tbl1',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th>Protein</th><th>Distributions</th><th>Function</th><th>Reference</th></tr></thead><tbody><tr><td align="left"><bold>Collagen</bold></td><td align="left">The skeletal systems and most soft tissues</td><td align="left">Provide tensile strength, connect the framework of tissue/organ, affect cell types disposition</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib9" ref-type="bibr">9</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Elastin</bold></td><td align="left">Most soft tissues, such as vasculature and muscle</td><td align="left">Provide elasticity, adjust mechanical properties, increase hemocompatibility</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib9" ref-type="bibr">9</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Fibronectin</bold></td><td align="left">Most organs/tissues</td><td align="left">Regulate cell behavior and function, guide branching morphogenesis in the development of complicated structures</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib8" ref-type="bibr">8</xref><xref rid="bib10" ref-type="bibr">10</xref></td></tr><tr><td align="left"><bold>Laminin</bold></td><td align="left">Cartilage, muscle</td><td align="left">Promote cell adhesion and migration, provide bioactive sites for cross-linking</td><td align="left"><xref rid="bib2" ref-type="bibr">2</xref><xref rid="bib8" ref-type="bibr">8</xref></td></tr><tr><td align="left"><bold>Matricellular Proteins</bold></td><td align="left">Vasculature</td><td align="left">Contain binding sites for ECM structural proteins and cell surface receptors, and modulate activities of specific growth factors</td><td align="left"><xref rid="bib9" ref-type="bibr">9</xref></td></tr></tbody></table>\n'},
#   'text': 'Protein\tDistributions\tFunction\tReference\t \tCollagen\tThe skeletal systems and most soft tissues\tProvide tensile strength, connect the framework of tissue/organ, affect cell types disposition\t\t \tElastin\tMost soft tissues, such as vasculature and muscle\tProvide elasticity, adjust mechanical properties, increase hemocompatibility\t\t \tFibronectin\tMost organs/tissues\tRegulate cell behavior and function, guide branching morphogenesis in the development of complicated structures\t\t \tLaminin\tCartilage, muscle\tPromote cell adhesion and migration, provide bioactive sites for cross-linking\t\t \tMatricellular Proteins\tVasculature\tContain binding sites for ECM structural proteins and cell surface receptors, and modulate activities of specific growth factors\t\t \t',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 2698,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Along with the rapid development of tissue engineering in the past decades, biological scaffolds have attracted significant interest in this field due to their great biocompatibility and bioactivity, and moderate mechanical performances for supporting cells. Among various types of scaffolds, decellularized extracellular matrix (dECM) scaffolds, which refer to biomaterials formed by human or animal organs/tissues with the removal of immunogenic cellular components via decellularized technologies, are under the spotlight. dECM scaffolds mainly consist of extracellular matrix (ECM), which is a three-dimensional (3D) framework containing extracellular macromolecules such as collagen, elastin, fibronectin, laminin, and matricellular proteins, as listed in Table 1. Meanwhile, the physicochemical signals and biological performance of dECM can be remained after decellularization, which provides a substrate for mechanical supporting and a biological 3D carrier for subsequent cell seeding. Therefore, such recellularized dECM can be implanted into patients for tissue engineering, including restoration of damaged organs, regeneration of endogenous tissues, and replacement of missing organs.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 3896,
#   'infons': {'file': 'gr1.jpg',
#    'id': 'fig1',
#    'section_type': 'FIG',
#    'type': 'fig_caption'},
#   'text': 'Timeline of decellularized extracellular matrix (dECM) scaffolds. Crude decellularization technique emerged in 1948, but the production of tissue-specific ECM was first reported in the 1970s. Intact acellular small intestinal submucosa matrices were produced for Achilles tendon repair in 1995. Whole rat decellularized hearts were first introduced in 2008, and decellularized lungs and acellular livers were fabricated in 2010, respectively. Orthotopic transplantation of the decellularized kidney was operated in 2013. dECM hydrogels were involved in 3D-bioprinting from 2014, followed by a 3D-printed construct using stem cell-laden dECM bioinks in 2017. Recently, various proteomics methods have been developed to analyze dECM materials in 2021.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 4646,
#   'infons': {'file': 'gr1.jpg',
#    'id': 'fig1',
#    'section_type': 'FIG',
#    'type': 'fig'},
#   'text': 'Fig. 1',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 4653,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': "Since the conception of decellularization was introduced, researchers have carried out numerous studies and explorations on the application of dECM scaffolds, as Fig. 1 shows the timeline of dECM. The first exploration of decellularization was achieved by Poel in 1948. After that, a few studies had reported decellularization technologies in the 1970s. In 1995, Badylak's team reported acellular scaffolds of small intestinal submucosa (SIS) for Achilles tendon repair. Since then, various 3D biological scaffolds derived from decellularized tissues or whole organs have been harvested and applied in a broad range of tissue engineerings, such as dermal tissue repair, heart valves replacement, and vascular tissue regeneration. A tremendous milestone of decellularized whole organs was reported by Ott in 2008, where a cadaveric ECM scaffold derived from rat heart was fabricated via perfusion decellularization. From then on, many research groups demonstrated the feasibility of obtaining acellular scaffolds from a variety of organs. In 2010, Ott, as well as Petersen, reported bioartificial lungs using decellularization process and verified that the acellular lung could participate in gas exchange. Similarly, Uygun obtained a transplantable liver scaffold via perfusion decellularization and demonstrated the recellularized grafts could normally support albumin secretion, urea synthesis and cytochrome P450 expression. In 2013, Song et al. introduced the orthotopic transplantation of decellularized kidneys in rodents and showed their functions of urine production and metabolites clearance, demonstrating the possibility and feasibility of fabricating dECM bioscaffolds with complex physiological functions. Moreover, with the steady improvement of decellularization technology, dECM scaffolds have been regarded as promising biomaterials to be solubilized into bioinks for 3D-bioprinting since the dECM could transform from a pre-gel fluid to hydrogel. In 2017, Jang used stem cell-laden heart tissue-derived dECM bioinks in 3D cell printing, in which cell-to-cell interactions and differentiation capability of stem cells are improved, and thus the pre-vascularized construct provided a cardiac-like microenvironment and resulted in beneficial effects on cardiac repair. Recently, researchers are paying more attention to the in-depth profiling of the proteome of decellularized ECM, in order to provide guidelines for comprehensively defining the ECM atlas and thus designing improved dECM scaffolds. In conclusion, the emergence and development of dECM scaffolds open a new avenue for human-organ/tissue-derived biomaterials in tissue engineering.",
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 7316,
#   'infons': {'section_type': 'INTRO', 'type': 'title_1'},
#   'text': 'Classification and fabrication of dECM scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 7365,
#   'infons': {'section_type': 'INTRO', 'type': 'title_2'},
#   'text': 'Classification of dECM scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 7398,
#   'infons': {'file': 'gr2.jpg',
#    'id': 'fig2',
#    'section_type': 'FIG',
#    'type': 'fig_caption'},
#   'text': 'Classification of dECM scaffolds. (a1) Organ/Tissue-derived dECM as a decellularized scaffold for tissue engineering. Human-derived organs/tissues undergo decellularization progress to obtain dECM scaffolds. Then cells are extracted, expanded and then seeded onto the dECM scaffolds to generate recellularized grafts for organ/tissue bioengineering. (a2) Cell-derived dECM as a decellularized scaffold for tissue engineering. Cell-deposited extracellular matrix (ECM) undergoes decellularization progress to obtain dECM scaffolds. Cells from other sources are recellularized onto the dECM scaffolds to generate bioengineered grafts for tissue engineering. (a) Recellularized stem cells and their classification.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 8110,
#   'infons': {'file': 'gr2.jpg',
#    'id': 'fig2',
#    'section_type': 'FIG',
#    'type': 'fig'},
#   'text': 'Fig. 2',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 8117,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Decellularization is a method of eliminating cellular components from organs/tissues/cells to generate a structural ECM template and maintain a biomimetic ECM microenvironment. According to the origins of ECM, dECM scaffolds are classified into three categories, including autogenous dECM, allogeneic dECM and xenogeneic dECM. Since autogenous dECM scaffolds face the situation of tissue limitations and surgical complications, most dECM scaffolds are from allogeneic or xenogeneic donor tissues; however, donor site morbidity, architecture and mass composition differences, and immunogenicity problems caused by incomplete decellularization may exist in allogeneic/xenogeneic dECM. According to the sources of ECM, dECM scaffolds can also be classified into two main categories, including organ/tissue-derived dECM scaffolds and cell-derived dECM scaffolds, as Fig. 2 shows.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 8993,
#   'infons': {'section_type': 'INTRO', 'type': 'title_3'},
#   'text': 'Organ/tissue(O/T)-derived dECM scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 9034,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'O/T-derived dECM scaffolds refer to the scaffolds derived from specific organs or tissues, which possess the natural 3D architecture from the whole organ or tissue by eliminating immunogenic cellular components and preserving non-immunogenic ECM (Fig. 2a1). These organs/tissues go through decellularization process, and the resulted acellular ECM scaffolds can be reseeded with specific cells to generate tissue-engineered grafts. O/T-derived dECM scaffolds serve as reservoirs for site-specific bioactive molecules and cell-matrix interactions, offering numerous advantages for tissue regeneration. First, since the native ECM contains memory factors and cues, O/T-derived dECM retains distinct tissue-specific memory that can drive tissue-specific differentiation. Second, O/T-derived dECM partly remains the sophisticated ECM structure and interior architecture, such as the morphology of pores and the alignment of collagen fibers, which might significantly regulate cell adhesion, proliferation and differentiation. Furthermore, their mechanical properties and microenvironment conditions are more similar to the native ECM than cell-deposited ECM discussed below.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 10205,
#   'infons': {'section_type': 'INTRO', 'type': 'title_3'},
#   'text': 'Cell-derived dECM scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 10233,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Cell-derived dECM scaffolds are alternative scaffolds to O/T-derived dECM scaffolds to provide a requisite niche. When cells are cultured in vitro, they can secrete cell-specific ECM, which can be decellularized subsequently to be a substratum for yielding large-quantity cells (Fig. 2a2). The acellular ECM, named cell-derived dECM, can be recellularized to form another excellent decellularized graft. These dECM scaffolds have attracted considerable interest since they possess several unique benefits. First, compared to the sophisticated fabrication of O/T-derived dECM scaffolds, acquiring cell-derived dECM scaffolds is relatively more exercisable to achieve, especially for obtaining dECM from certain progenitors or stem cells. Second, cell-derived ECM scaffolds can reduce the risk of pathogen transfer caused by allogenic ECM and eliminate adverse host immune responses induced by xenogeneic ECM. Furthermore, in-vitro cultured cell-derived dECM can be more operable to modify and graft on other surfaces of biomaterials such as hydroxyapatite and biphasic calcium phosphate.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 11320,
#   'infons': {'section_type': 'INTRO', 'type': 'title_2'},
#   'text': 'Fabrication of dECM scaffolds',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 11350,
#   'infons': {'file': 'gr3.jpg',
#    'id': 'fig3',
#    'section_type': 'FIG',
#    'type': 'fig_caption'},
#   'text': 'Decellularization methods: physical treatments, chemical treatments, and enzymatic treatments. The typical processes for each treatment are cataloged.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 11501,
#   'infons': {'file': 'gr3.jpg',
#    'id': 'fig3',
#    'section_type': 'FIG',
#    'type': 'fig'},
#   'text': 'Fig. 3',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 11508,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Ideal decellularization refers to the complete removal of cellular components with remaining the original architecture and composition, biochemical and mechanical properties of the native ECM. To date, there is no methodological gold standard of decellularization, which is largely dependent on multiple factors of the source tissue, such as species and ages, anatomical location and sizes; however, researchers have developed a wide variety of decellularization protocols, including physical, chemical, enzymatic treatments and a combination of these approaches (Fig. 3).',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 12081,
#   'infons': {'section_type': 'INTRO', 'type': 'title_3'},
#   'text': 'Physical treatments',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 12101,
#   'infons': {'file': 'tbl2.xml',
#    'id': 'tbl2',
#    'section_type': 'TABLE',
#    'type': 'table_caption'},
#   'text': 'List of physical treatments used for decellularization.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 12157,
#   'infons': {'file': 'tbl2.xml',
#    'id': 'tbl2',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th><italic>Method</italic></th><th>Mechanism</th><th>Disadvantages</th><th>Reference</th></tr></thead><tbody><tr><td rowspan="2" align="left"><italic>Freeze-thaw cycles</italic></td><td rowspan="2" align="left">Disrupt cell membranes and cause cell lysis by forming intracellular ice crystals</td><td align="left">Disrupt ECM microstructure by ice crystals.</td><td rowspan="2" align="left"><xref rid="bib42" ref-type="bibr">42</xref><xref rid="bib43" ref-type="bibr">43</xref><xref rid="bib72" ref-type="bibr">[72]</xref><xref rid="bib73" ref-type="bibr">[73]</xref><xref rid="bib74" ref-type="bibr">[74]</xref><xref rid="bib75" ref-type="bibr">[75]</xref></td></tr><tr><td align="left">Require subsequent treatments for the removal of cellular contents</td></tr><tr><td rowspan="2" align="left"><italic>Immersion and agitation</italic></td><td rowspan="2" align="left">Rupture tissues and cells, and isolate cells from basement membranes</td><td align="left">Alter ECM architecture.</td><td rowspan="2" align="left"><xref rid="bib42" ref-type="bibr">42</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib65" ref-type="bibr">65</xref><xref rid="bib66" ref-type="bibr">66</xref><xref rid="bib70" ref-type="bibr">70</xref><xref rid="bib72" ref-type="bibr">72</xref></td></tr><tr><td align="left">Need optimal standards for mechanical force and exposure time</td></tr><tr><td rowspan="2" align="left"><italic>Perfusion</italic></td><td rowspan="2" align="left">Remove cells from ECM and help the removal of cellular components and debris within the organ\'s natural vasculature</td><td align="left">Cannot process tissues without innate vasculature.</td><td rowspan="2" align="left"><xref rid="bib14" ref-type="bibr">14</xref><xref rid="bib49" ref-type="bibr">[49]</xref><xref rid="bib50" ref-type="bibr">[50]</xref><xref rid="bib51" ref-type="bibr">[51]</xref><xref rid="bib52" ref-type="bibr">[52]</xref><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib76" ref-type="bibr">[76]</xref><xref rid="bib77" ref-type="bibr">[77]</xref><xref rid="bib78" ref-type="bibr">[78]</xref><xref rid="bib79" ref-type="bibr">[79]</xref><xref rid="bib80" ref-type="bibr">[80]</xref><xref rid="bib81" ref-type="bibr">[81]</xref></td></tr><tr><td align="left">Sophisticated to operate the perfusion devices</td></tr><tr><td rowspan="2" align="left"><italic>Scraping</italic></td><td rowspan="2" align="left">Mechanically remove cells from ECM surface</td><td align="left">Damage underlying basement membranes.</td><td rowspan="2" align="left"><xref rid="bib82" ref-type="bibr">82</xref></td></tr><tr><td align="left">Need standards for controlling mechanical force</td></tr><tr><td align="left"><italic>Sonication</italic></td><td align="left">Generate acoustic cavitation bubbles, induce shear stress effect, and thus rupture the cell membrane; Ease and assist the penetration of agents by emitting the vibration, and help cellular debris removal</td><td align="left">High power or longer duration of sonication could disrupt the main structural fibers and produce adverse effects on the vascular tissues</td><td align="left"><xref rid="bib83" ref-type="bibr">[83]</xref><xref rid="bib84" ref-type="bibr">[84]</xref><xref rid="bib85" ref-type="bibr">[85]</xref></td></tr><tr><td align="left"><italic>Supercritical fluids</italic></td><td align="left">Facilitate chemical exposure, and lead to cell removal</td><td align="left">Not yet widely used</td><td align="left"><xref rid="bib86" ref-type="bibr">[86]</xref><xref rid="bib87" ref-type="bibr">[87]</xref><xref rid="bib88" ref-type="bibr">[88]</xref></td></tr><tr><td align="left"><italic>Pressure gradient/Convective flow</italic></td><td align="left">Burst cells, and aid in the delivery of solutions to force cellular components and soluble proteins out of tissues</td><td align="left">Make solutions difficult to penetrate ECM due to the cons ...
#   'text': 'Table 2\t \t',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 12168,
#   'infons': {'file': 'tbl2.xml',
#    'id': 'tbl2',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th><italic>Method</italic></th><th>Mechanism</th><th>Disadvantages</th><th>Reference</th></tr></thead><tbody><tr><td rowspan="2" align="left"><italic>Freeze-thaw cycles</italic></td><td rowspan="2" align="left">Disrupt cell membranes and cause cell lysis by forming intracellular ice crystals</td><td align="left">Disrupt ECM microstructure by ice crystals.</td><td rowspan="2" align="left"><xref rid="bib42" ref-type="bibr">42</xref><xref rid="bib43" ref-type="bibr">43</xref><xref rid="bib72" ref-type="bibr">[72]</xref><xref rid="bib73" ref-type="bibr">[73]</xref><xref rid="bib74" ref-type="bibr">[74]</xref><xref rid="bib75" ref-type="bibr">[75]</xref></td></tr><tr><td align="left">Require subsequent treatments for the removal of cellular contents</td></tr><tr><td rowspan="2" align="left"><italic>Immersion and agitation</italic></td><td rowspan="2" align="left">Rupture tissues and cells, and isolate cells from basement membranes</td><td align="left">Alter ECM architecture.</td><td rowspan="2" align="left"><xref rid="bib42" ref-type="bibr">42</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib65" ref-type="bibr">65</xref><xref rid="bib66" ref-type="bibr">66</xref><xref rid="bib70" ref-type="bibr">70</xref><xref rid="bib72" ref-type="bibr">72</xref></td></tr><tr><td align="left">Need optimal standards for mechanical force and exposure time</td></tr><tr><td rowspan="2" align="left"><italic>Perfusion</italic></td><td rowspan="2" align="left">Remove cells from ECM and help the removal of cellular components and debris within the organ\'s natural vasculature</td><td align="left">Cannot process tissues without innate vasculature.</td><td rowspan="2" align="left"><xref rid="bib14" ref-type="bibr">14</xref><xref rid="bib49" ref-type="bibr">[49]</xref><xref rid="bib50" ref-type="bibr">[50]</xref><xref rid="bib51" ref-type="bibr">[51]</xref><xref rid="bib52" ref-type="bibr">[52]</xref><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib76" ref-type="bibr">[76]</xref><xref rid="bib77" ref-type="bibr">[77]</xref><xref rid="bib78" ref-type="bibr">[78]</xref><xref rid="bib79" ref-type="bibr">[79]</xref><xref rid="bib80" ref-type="bibr">[80]</xref><xref rid="bib81" ref-type="bibr">[81]</xref></td></tr><tr><td align="left">Sophisticated to operate the perfusion devices</td></tr><tr><td rowspan="2" align="left"><italic>Scraping</italic></td><td rowspan="2" align="left">Mechanically remove cells from ECM surface</td><td align="left">Damage underlying basement membranes.</td><td rowspan="2" align="left"><xref rid="bib82" ref-type="bibr">82</xref></td></tr><tr><td align="left">Need standards for controlling mechanical force</td></tr><tr><td align="left"><italic>Sonication</italic></td><td align="left">Generate acoustic cavitation bubbles, induce shear stress effect, and thus rupture the cell membrane; Ease and assist the penetration of agents by emitting the vibration, and help cellular debris removal</td><td align="left">High power or longer duration of sonication could disrupt the main structural fibers and produce adverse effects on the vascular tissues</td><td align="left"><xref rid="bib83" ref-type="bibr">[83]</xref><xref rid="bib84" ref-type="bibr">[84]</xref><xref rid="bib85" ref-type="bibr">[85]</xref></td></tr><tr><td align="left"><italic>Supercritical fluids</italic></td><td align="left">Facilitate chemical exposure, and lead to cell removal</td><td align="left">Not yet widely used</td><td align="left"><xref rid="bib86" ref-type="bibr">[86]</xref><xref rid="bib87" ref-type="bibr">[87]</xref><xref rid="bib88" ref-type="bibr">[88]</xref></td></tr><tr><td align="left"><italic>Pressure gradient/Convective flow</italic></td><td align="left">Burst cells, and aid in the delivery of solutions to force cellular components and soluble proteins out of tissues</td><td align="left">Make solutions difficult to penetrate ECM due to the cons ...
#   'text': "Method\tMechanism\tDisadvantages\tReference\t \tFreeze-thaw cycles\tDisrupt cell membranes and cause cell lysis by forming intracellular ice crystals\tDisrupt ECM microstructure by ice crystals.\t\t \tRequire subsequent treatments for the removal of cellular contents\t \tImmersion and agitation\tRupture tissues and cells, and isolate cells from basement membranes\tAlter ECM architecture.\t\t \tNeed optimal standards for mechanical force and exposure time\t \tPerfusion\tRemove cells from ECM and help the removal of cellular components and debris within the organ's natural vasculature\tCannot process tissues without innate vasculature.\t\t \tSophisticated to operate the perfusion devices\t \tScraping\tMechanically remove cells from ECM surface\tDamage underlying basement membranes.\t\t \tNeed standards for controlling mechanical force\t \tSonication\tGenerate acoustic cavitation bubbles, induce shear stress effect, and thus rupture the cell membrane; Ease and assist the penetration of agents by emitting the vibration, and help cellular debris removal\tHigh power or longer duration of sonication could disrupt the main structural fibers and produce adverse effects on the vascular tissues\t\t \tSupercritical fluids\tFacilitate chemical exposure, and lead to cell removal\tNot yet widely used\t\t \tPressure gradient/Convective flow\tBurst cells, and aid in the delivery of solutions to force cellular components and soluble proteins out of tissues\tMake solutions difficult to penetrate ECM due to the constantly high pressure\t\t \tPressurization\tResult in cell lysis\tDenature the proteins, and disrupt the ECM structure by formed ice crystals.\t\t \tExpensive to operate\t \tElectroporation\tCause micropore formation in cell membranes and lead to cell lysis\tHard to process large-sized tissues.\t\t \tUsed solvents can be toxic\t \t",
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 13960,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Physical treatments modulate physical characteristics, such as temperature, force and pressure, to facilitate rinsing of detergent solutions, disruption of cell membranes, and removal of cellular contents. Particularly, freeze-thaw cycles, immersion and agitation, and perfusion are widely used for decellularization. Herein, various physical treatments, and their mechanisms and disadvantages are summarized in Table 2.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 14381,
#   'infons': {'section_type': 'INTRO', 'type': 'title_4'},
#   'text': 'Freeze-thaw cycles',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 14400,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Freeze-thaw cycles refer to a repetitive decellularization process that involves freeze-drying in nitrogen and subsequent thawing in buffer solution. Freeze-thaw procedures are operated to disintegrate cell membranes, promote cell lysis and detach cells from the ECM network by forming intracellular ice crystals. Freeze-thaw cycles have been used for both O/T-derived ECM and cell-derived ECM due to its improved decellularization efficiency, reduced residual chemicals and cytotoxicity, and well-preserved biochemical composition, biomechanical performance and tissue structures. The decellularization efficiency is mainly determined by its cooling/thawing rate, the setpoint temperature, processing time, and repetitive cycles. Freeze-thaw cycles is typically combined with chemical or enzymatic methods to form a porous structure, rendering ECM susceptible to subsequent chemical treatments. However, without chemical or enzymatic agents, cyclic freeze-thawing could also achieve satisfactory results. For instance, repetitive freeze-thawing procedures could deplete all native cells from peripheral nerve sheath, while basal lamina maintains integrity and flexibility.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 15574,
#   'infons': {'section_type': 'INTRO', 'type': 'title_4'},
#   'text': 'Perfusion',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 15584,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Perfusion is a typical decellularized route for larger, thicker tissues or whole organs, which refers to cannulating organs/tissues and subsequently establishing a channel for circulating agents through their intrinsic vascular system. The efficiency of perfusion is primarily determined by perfusion route (artery or portal vein route), infusion mode (antegrade or retrograde), perfusion paraments (pressure, temperature, and flow rate), types and concentrations of perfusate, and the dimension of organ/tissue. This method has attracted great attention because it intensely improves the decellularization efficiency by rapid accessing to the whole organ and homogeneous perfusion through the native vasculature. Second, after perfusion, the intact and intricate vascular network, the vital construction of the whole organ, is maintained, including portal vein, artery inflow, and venous outflow, which is essential for the transportation of nutrition and oxygen within organs/tissues. However, perfusion requires additional hardware and complex setup for flow control, such as an infusion/withdrawal syringe pump and pressure transducer.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 16724,
#   'infons': {'section_type': 'INTRO', 'type': 'title_4'},
#   'text': 'Immersion and agitation',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 16748,
#   'infons': {'section_type': 'INTRO', 'type': 'paragraph'},
#   'text': 'Compared with perfusion treatment, immersion and agitation is a more appropriate method for small, fragile and thin sections of organs as well as tissues without innate vascular structures. Immersion and agitation refers to the method of submerging tissues into decellularization solutions with constant mechanical agitation, whose efficiency depends on different paraments, including agitation intensity, decellularization agent and tissue dimension. After immersing tissues in the agents, agitation facilitates the rupture of cells, the detachment of cells from basement membranes, and the removal of cellular components. As an optimal physical way to decellularize, the utilization of immersion and agitation owns plenty of advantages. First, using dynamic immersion and agitation can attain a more homogeneous detergent exposure than static decellularization, and achieve a better decellularization effect with less exposure time to aggressive decellularization agents. Second, this method does not significantly affect the ECM surface structure, collagen structure and integrity, mechanical strength, and GAG content. Third, compared to whole organ perfusion, this method is a more accessible and easily executed procedure. However, compared with perfusion, using this method may cause more damages to tissues due to the limited diffusion of chemicals by agitation.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 18119,
#   'infons': {'section_type': 'INTRO', 'type': 'title_3'},
#   'text': 'Chemical treatments',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 18139,
#   'infons': {'file': 'tbl3.xml',
#    'id': 'tbl3',
#    'section_type': 'TABLE',
#    'type': 'table_caption'},
#   'text': 'List of chemical treatments used for decellularization.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 18195,
#   'infons': {'file': 'tbl3.xml',
#    'id': 'tbl3',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th><italic>Method</italic></th><th><italic>Typical Agents</italic></th><th><italic>Mechanism</italic></th><th><italic>Disadvantages</italic></th><th><italic>Reference</italic></th></tr></thead><tbody><tr><td rowspan="3" align="left"><italic>Ionic detergents</italic></td><td align="left">SDS,</td><td rowspan="3" align="left">Solubilize cytoplasmic membranes, nucleic membranes and nucleic acids, and dissociate deoxyribonucleic acid (DNA) from protein</td><td align="left">Damage ECM structure and collagen integrity.</td><td rowspan="3" align="left"><xref rid="bib36" ref-type="bibr">36</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib51" ref-type="bibr">51</xref><xref rid="bib58" ref-type="bibr">58</xref><xref rid="bib114" ref-type="bibr">114</xref><xref rid="bib115" ref-type="bibr">115</xref></td></tr><tr><td align="left">SDC,</td><td align="left">Reduce the contents of glycosaminoglycan (GAG) and growth factors</td></tr><tr><td align="left">Triton X-200</td><td/></tr><tr><td rowspan="3" align="left"><italic>Non-ionic detergents</italic></td><td rowspan="3" align="left">Triton X-100</td><td rowspan="3" align="left">Solubilize cell membranes and dissociate DNA from proteins (especially suitable for cell-derived dECM) without disrupting protein-protein interactions</td><td align="left">Alter the ECM architecture.</td><td rowspan="3" align="left"><xref rid="bib43" ref-type="bibr">43</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib51" ref-type="bibr">51</xref><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib58" ref-type="bibr">58</xref><xref rid="bib107" ref-type="bibr">107</xref><xref rid="bib108" ref-type="bibr">108</xref><xref rid="bib115" ref-type="bibr">115</xref><xref rid="bib116" ref-type="bibr">116</xref></td></tr><tr><td align="left">Reduce laminins/fibronectin content.</td></tr><tr><td align="left">Remove cells incompletely</td></tr><tr><td rowspan="3" align="left"><italic>Zwitterionic detergents</italic></td><td align="left">CHAPS,</td><td rowspan="3" align="left">Solubilize cell membranes and dissociate DNA from proteins by disrupting DNA-protein, lipid-lipid, lipid-protein interactions</td><td rowspan="3" align="left">Disrupt and dissociate proteins in the ECM</td><td rowspan="3" align="left"><xref rid="bib100" ref-type="bibr">100</xref><xref rid="bib117" ref-type="bibr">[117]</xref><xref rid="bib118" ref-type="bibr">[118]</xref><xref rid="bib119" ref-type="bibr">[119]</xref><xref rid="bib120" ref-type="bibr">[120]</xref></td></tr><tr><td align="left">SB-10,</td></tr><tr><td align="left">SB-16</td></tr><tr><td rowspan="2" align="left"><italic>Acids</italic></td><td align="left">Peracetic acid,</td><td rowspan="2" align="left">Disrupt cell membranes, solubilize cytoplasmic organelles, induce cell lysis, denature proteins and catalyze hydrolytic degradation of biomolecules</td><td align="left">Damage ECM architecture.</td><td rowspan="2" align="left"><xref rid="bib76" ref-type="bibr">76</xref><xref rid="bib105" ref-type="bibr">105</xref><xref rid="bib114" ref-type="bibr">114</xref><xref rid="bib121" ref-type="bibr">121</xref></td></tr><tr><td align="left">Hydrochloric acid</td><td align="left">Affect intracellular molecules such as GAG</td></tr><tr><td rowspan="2" align="left"><italic>Bases</italic></td><td rowspan="2" align="left">Ammonium hydroxide</td><td rowspan="2" align="left">Solubilize cytoplasmic components, disrupt nucleic acids and catalyze hydrolytic degradation of biomolecules</td><td align="left">Influence GAG content, collagen and growth factors.</td><td rowspan="2" align="left"><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib61" ref-type="bibr">61</xref><xref rid="bib105" ref-type="bibr">105</xref></td></tr><tr><td align="left">Weaken mechanical properties</td></tr><tr><td align="left"><italic>Hypertonic solutions</italic></td><td align="left">Sodium chloride</td> ...
#   'text': 'Table 3\t \t',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 18206,
#   'infons': {'file': 'tbl3.xml',
#    'id': 'tbl3',
#    'section_type': 'TABLE',
#    'type': 'table',
#    'xml': '<?xml version="1.0" encoding="UTF-8"?>\n<table frame="hsides" rules="groups"><thead><tr><th><italic>Method</italic></th><th><italic>Typical Agents</italic></th><th><italic>Mechanism</italic></th><th><italic>Disadvantages</italic></th><th><italic>Reference</italic></th></tr></thead><tbody><tr><td rowspan="3" align="left"><italic>Ionic detergents</italic></td><td align="left">SDS,</td><td rowspan="3" align="left">Solubilize cytoplasmic membranes, nucleic membranes and nucleic acids, and dissociate deoxyribonucleic acid (DNA) from protein</td><td align="left">Damage ECM structure and collagen integrity.</td><td rowspan="3" align="left"><xref rid="bib36" ref-type="bibr">36</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib51" ref-type="bibr">51</xref><xref rid="bib58" ref-type="bibr">58</xref><xref rid="bib114" ref-type="bibr">114</xref><xref rid="bib115" ref-type="bibr">115</xref></td></tr><tr><td align="left">SDC,</td><td align="left">Reduce the contents of glycosaminoglycan (GAG) and growth factors</td></tr><tr><td align="left">Triton X-200</td><td/></tr><tr><td rowspan="3" align="left"><italic>Non-ionic detergents</italic></td><td rowspan="3" align="left">Triton X-100</td><td rowspan="3" align="left">Solubilize cell membranes and dissociate DNA from proteins (especially suitable for cell-derived dECM) without disrupting protein-protein interactions</td><td align="left">Alter the ECM architecture.</td><td rowspan="3" align="left"><xref rid="bib43" ref-type="bibr">43</xref><xref rid="bib50" ref-type="bibr">50</xref><xref rid="bib51" ref-type="bibr">51</xref><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib58" ref-type="bibr">58</xref><xref rid="bib107" ref-type="bibr">107</xref><xref rid="bib108" ref-type="bibr">108</xref><xref rid="bib115" ref-type="bibr">115</xref><xref rid="bib116" ref-type="bibr">116</xref></td></tr><tr><td align="left">Reduce laminins/fibronectin content.</td></tr><tr><td align="left">Remove cells incompletely</td></tr><tr><td rowspan="3" align="left"><italic>Zwitterionic detergents</italic></td><td align="left">CHAPS,</td><td rowspan="3" align="left">Solubilize cell membranes and dissociate DNA from proteins by disrupting DNA-protein, lipid-lipid, lipid-protein interactions</td><td rowspan="3" align="left">Disrupt and dissociate proteins in the ECM</td><td rowspan="3" align="left"><xref rid="bib100" ref-type="bibr">100</xref><xref rid="bib117" ref-type="bibr">[117]</xref><xref rid="bib118" ref-type="bibr">[118]</xref><xref rid="bib119" ref-type="bibr">[119]</xref><xref rid="bib120" ref-type="bibr">[120]</xref></td></tr><tr><td align="left">SB-10,</td></tr><tr><td align="left">SB-16</td></tr><tr><td rowspan="2" align="left"><italic>Acids</italic></td><td align="left">Peracetic acid,</td><td rowspan="2" align="left">Disrupt cell membranes, solubilize cytoplasmic organelles, induce cell lysis, denature proteins and catalyze hydrolytic degradation of biomolecules</td><td align="left">Damage ECM architecture.</td><td rowspan="2" align="left"><xref rid="bib76" ref-type="bibr">76</xref><xref rid="bib105" ref-type="bibr">105</xref><xref rid="bib114" ref-type="bibr">114</xref><xref rid="bib121" ref-type="bibr">121</xref></td></tr><tr><td align="left">Hydrochloric acid</td><td align="left">Affect intracellular molecules such as GAG</td></tr><tr><td rowspan="2" align="left"><italic>Bases</italic></td><td rowspan="2" align="left">Ammonium hydroxide</td><td rowspan="2" align="left">Solubilize cytoplasmic components, disrupt nucleic acids and catalyze hydrolytic degradation of biomolecules</td><td align="left">Influence GAG content, collagen and growth factors.</td><td rowspan="2" align="left"><xref rid="bib57" ref-type="bibr">57</xref><xref rid="bib61" ref-type="bibr">61</xref><xref rid="bib105" ref-type="bibr">105</xref></td></tr><tr><td align="left">Weaken mechanical properties</td></tr><tr><td align="left"><italic>Hypertonic solutions</italic></td><td align="left">Sodium chloride</td> ...
#   'text': 'Method\tTypical Agents\tMechanism\tDisadvantages\tReference\t \tIonic detergents\tSDS,\tSolubilize cytoplasmic membranes, nucleic membranes and nucleic acids, and dissociate deoxyribonucleic acid (DNA) from protein\tDamage ECM structure and collagen integrity.\t\t \tSDC,\tReduce the contents of glycosaminoglycan (GAG) and growth factors\t \tTriton X-200\t\t \tNon-ionic detergents\tTriton X-100\tSolubilize cell membranes and dissociate DNA from proteins (especially suitable for cell-derived dECM) without disrupting protein-protein interactions\tAlter the ECM architecture.\t\t \tReduce laminins/fibronectin content.\t \tRemove cells incompletely\t \tZwitterionic detergents\tCHAPS,\tSolubilize cell membranes and dissociate DNA from proteins by disrupting DNA-protein, lipid-lipid, lipid-protein interactions\tDisrupt and dissociate proteins in the ECM\t\t \tSB-10,\t \tSB-16\t \tAcids\tPeracetic acid,\tDisrupt cell membranes, solubilize cytoplasmic organelles, induce cell lysis, denature proteins and catalyze hydrolytic degradation of biomolecules\tDamage ECM architecture.\t\t \tHydrochloric acid\tAffect intracellular molecules such as GAG\t \tBases\tAmmonium hydroxide\tSolubilize cytoplasmic components, disrupt nucleic acids and catalyze hydrolytic degradation of biomolecules\tInfluence GAG content, collagen and growth factors.\t\t \tWeaken mechanical properties\t \tHypertonic solutions\tSodium chloride\tRupture cell membranes and lyse cells by osmotic shock\tDifficult to remove DNA remnants\t\t \tHypotonic solutions\tTris-HCl\tInduce cell lysis, and detach DNA from proteins\tDifficult to remove DNA remnants\t\t \tOrganic solvents\tEthanol, Methanol, Acetones\tExtract the lipid of the ECM and cause tissue dehydration, leading to cell membranes solubilization and cell lysis\tCross-link and precipitate proteins, including collagen.\t\t \tChelators\tEDTA, EGTA\tDissociate cells and ECM by binding divalent metal ions necessary for cell adhesion\tDisrupt protein-protein interactions, and denature proteins in ECM\t\t \t',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 20171,
# ...
#   'relations': []},
#  {'offset': 78695,
#   'infons': {'name_0': 'surname:Morais;given-names:A.D.',
#    'name_1': 'surname:Vieira;given-names:S.',
#    'name_2': 'surname:Zhao;given-names:X.L.',
#    'name_3': 'surname:Mao;given-names:Z.W.',
#    'name_4': 'surname:Gao;given-names:C.Y.',
#    'name_5': 'surname:Oliveira;given-names:J.M.',
#    'name_6': 'surname:Reis;given-names:R.L.',
#    'section_type': 'REF',
#    'source': 'Adv. Healthcare Mater.',
#    'type': 'ref',
#    'volume': '9',
#    'year': '2020'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78696,
#   'infons': {'fpage': '813',
#    'name_0': 'surname:Croce;given-names:S.',
#    'name_1': 'surname:Peloso;given-names:A.',
#    'name_2': 'surname:Zoro;given-names:T.',
#    'name_3': 'surname:Avanzini;given-names:M.A.',
#    'name_4': 'surname:Cobianchi;given-names:L.',
#    'section_type': 'REF',
#    'source': 'Biomolecules',
#    'type': 'ref',
#    'volume': '9',
#    'year': '2019'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78697,
#   'infons': {'fpage': '166',
#    'lpage': '176',
#    'name_0': 'surname:Struecker;given-names:B.',
#    'name_1': 'surname:Raschzok;given-names:N.',
#    'name_2': 'surname:Sauer;given-names:I.M.',
#    'pub-id_pmid': '24166083',
#    'section_type': 'REF',
#    'source': 'Nat. Rev. Gastroenterol. Hepatol.',
#    'type': 'ref',
#    'volume': '11',
#    'year': '2014'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78698,
#   'infons': {'fpage': '314',
#    'lpage': '326',
#    'name_0': 'surname:Ansari;given-names:T.',
#    'name_1': 'surname:Southgate;given-names:A.',
#    'name_2': 'surname:Obiri-Yeboa;given-names:I.',
#    'name_3': 'surname:Jones;given-names:L.G.',
#    'name_4': 'surname:Greco;given-names:K.',
#    'name_5': 'surname:Olayanju;given-names:A.',
#    'name_6': 'surname:Mbundi;given-names:L.',
#    'name_7': 'surname:Somasundaram;given-names:M.',
#    'name_8': 'surname:Davidson;given-names:B.',
#    'name_9': 'surname:Sibbons;given-names:P.D.',
#    'section_type': 'REF',
#    'source': 'Stem Cell. Dev.',
#    'type': 'ref',
#    'volume': '29',
#    'year': '2020'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78699,
#   'infons': {'fpage': 'E347',
#    'lpage': 'E355',
#    'name_0': 'surname:Mattei;given-names:G.',
#    'name_1': 'surname:Magliaro;given-names:C.',
#    'name_2': 'surname:Pirone;given-names:A.',
#    'name_3': 'surname:Ahluwalia;given-names:A.',
#    'pub-id_pmid': '28543403',
#    'section_type': 'REF',
#    'source': 'Artif. Organs',
#    'type': 'ref',
#    'volume': '41',
#    'year': '2017'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78700,
#   'infons': {'fpage': '5534',
#    'name_0': 'surname:Mazza;given-names:G.',
#    'name_1': 'surname:Al-Akkad;given-names:W.',
#    'name_10': 'surname:Willacy;given-names:O.',
#    'name_11': 'surname:Shaeri;given-names:M.',
#    'name_12': 'surname:Burns;given-names:A.',
#    'name_13': 'surname:Malago;given-names:M.',
#    'name_14': 'surname:Gilbertson;given-names:J.',
#    'name_15': 'surname:Rendell;given-names:N.',
#    'name_16': 'surname:Moore;given-names:K.',
#    'name_17': 'surname:Hughes;given-names:D.',
#    'name_18': 'surname:Notingher;given-names:I.',
#    'name_19': 'surname:Jell;given-names:G.',
#    'name_2': 'surname:Telese;given-names:A.',
#    'name_20': 'surname:Hernandez;given-names:A.D.',
#    'name_21': 'surname:De Coppi;given-names:P.',
#    'name_22': 'surname:Rombouts;given-names:K.',
#    'name_23': 'surname:Pinzani;given-names:M.',
#    'name_3': 'surname:Longato;given-names:L.',
#    'name_4': 'surname:Urbani;given-names:L.',
#    'name_5': 'surname:Robinson;given-names:B.',
#    'name_6': 'surname:Hall;given-names:A.',
#    'name_7': 'surname:Kong;given-names:K.',
#    'name_8': 'surname:Frenguelli;given-names:L.',
#    'name_9': 'surname:Marrone;given-names:G.',
#    'pub-id_pmid': '28717194',
#    'section_type': 'REF',
#    'source': 'Sci. Rep.',
#    'type': 'ref',
#    'volume': '7',
#    'year': '2017'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78701,
#   'infons': {'fpage': 'E25',
#    'lpage': 'E38',
#    'name_0': 'surname:Zhou;given-names:P.C.',
#    'name_1': 'surname:Huang;given-names:Y.',
#    'name_10': 'surname:Huang;given-names:H.',
#    'name_11': 'surname:Lu;given-names:Y.H.',
#    'name_12': 'surname:Wang;given-names:Z.W.',
#    'name_2': 'surname:Guo;given-names:Y.B.',
#    'name_3': 'surname:Wang;given-names:L.',
#    'name_4': 'surname:Ling;given-names:C.C.',
#    'name_5': 'surname:Guo;given-names:Q.S.',
#    'name_6': 'surname:Wang;given-names:Y.',
#    'name_7': 'surname:Zhu;given-names:S.J.',
#    'name_8': 'surname:Fan;given-names:X.J.',
#    'name_9': 'surname:Zhu;given-names:M.Y.',
#    'pub-id_pmid': '26637111',
#    'section_type': 'REF',
#    'source': 'Artif. Organs',
#    'type': 'ref',
#    'volume': '40',
#    'year': '2016'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78702,
#   'infons': {'fpage': '183',
#    'lpage': '192',
#    'name_0': 'surname:Petrosyan;given-names:A.',
#    'name_1': 'surname:Zanusso;given-names:I.',
#    'name_2': 'surname:Lavarreda-Pearce;given-names:M.',
#    'name_3': 'surname:Leslie;given-names:S.',
#    'name_4': 'surname:Sedrakyan;given-names:S.',
#    'name_5': 'surname:De Filippo;given-names:R.E.',
#    'name_6': 'surname:Orlando;given-names:G.',
#    'name_7': 'surname:Da Sacco;given-names:S.',
#    'name_8': 'surname:Perin;given-names:L.',
#    'section_type': 'REF',
#    'source': 'Tissue Eng. B Rev.',
#    'type': 'ref',
#    'volume': '22',
#    'year': '2016'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78703,
#   'infons': {'fpage': '2034',
#    'lpage': '2047',
#    'name_0': 'surname:Hussein;given-names:K.H.',
#    'name_1': 'surname:Saleh;given-names:T.',
#    'name_2': 'surname:Ahmed;given-names:E.',
#    'name_3': 'surname:Kwak;given-names:H.H.',
#    'name_4': 'surname:Park;given-names:K.M.',
#    'name_5': 'surname:Yang;given-names:S.R.',
#    'name_6': 'surname:Kang;given-names:B.J.',
#    'name_7': 'surname:Choi;given-names:K.Y.',
#    'name_8': 'surname:Kang;given-names:K.S.',
#    'name_9': 'surname:Woo;given-names:H.M.',
#    'section_type': 'REF',
#    'source': 'J. Biomed. Mater. Res.',
#    'type': 'ref',
#    'volume': '106',
#    'year': '2018'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78704,
#   'infons': {'fpage': '1352',
#    'lpage': '1360',
#    'name_0': 'surname:He;given-names:M.',
#    'name_1': 'surname:Callanan;given-names:A.',
#    'name_2': 'surname:Lagaras;given-names:K.',
#    'name_3': 'surname:Steele;given-names:J.A.M.',
#    'name_4': 'surname:Stevens;given-names:M.M.',
#    'pub-id_pmid': '27062181',
#    'section_type': 'REF',
#    'source': 'J. Biomed. Mater. Res. B Appl. Biomater.',
#    'type': 'ref',
#    'volume': '105',
#    'year': '2017'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78705,
#   'infons': {'fpage': '64',
#    'lpage': '75',
#    'name_0': 'surname:Caralt;given-names:M.',
#    'name_1': 'surname:Uzarski;given-names:J.S.',
#    'name_10': 'surname:Zhang;given-names:Z.J.',
#    'name_11': 'surname:Abecassis;given-names:M.M.',
#    'name_12': 'surname:Wertheim;given-names:J.A.',
#    'name_2': 'surname:Iacob;given-names:S.',
#    'name_3': 'surname:Obergfell;given-names:K.P.',
#    'name_4': 'surname:Berg;given-names:N.',
#    'name_5': 'surname:Bijonowski;given-names:B.M.',
#    'name_6': 'surname:Kiefer;given-names:K.M.',
#    'name_7': 'surname:Ward;given-names:H.H.',
#    'name_8': 'surname:Wandinger-Ness;given-names:A.',
#    'name_9': 'surname:Miller;given-names:W.M.',
#    'pub-id_pmid': '25403742',
#    'section_type': 'REF',
#    'source': 'Am. J. Transplant.',
#    'type': 'ref',
#    'volume': '15',
#    'year': '2015'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78706,
#   'infons': {'fpage': '1328',
#    'lpage': '1343',
#    'name_0': 'surname:Leuning;given-names:D.G.',
#    'name_1': 'surname:Witjas;given-names:F.M.R.',
#    'name_10': 'surname:de Boer;given-names:H.',
#    'name_11': 'surname:Wang;given-names:G.',
#    'name_12': 'surname:LaPointe;given-names:V.L.S.',
#    'name_13': 'surname:van der Vlag;given-names:J.',
#    'name_14': 'surname:van Kooten;given-names:C.',
#    'name_15': 'surname:van den Berg;given-names:B.M.',
#    'name_16': 'surname:Little;given-names:M.H.',
#    'name_17': 'surname:Engelse;given-names:M.A.',
#    'name_18': 'surname:Rabelink;given-names:T.J.',
#    'name_2': 'surname:Maanaoui;given-names:M.',
#    'name_3': 'surname:de Graaf;given-names:A.M.A.',
#    'name_4': 'surname:Lievers;given-names:E.',
#    'name_5': 'surname:Geuens;given-names:T.',
#    'name_6': 'surname:Avramut;given-names:C.M.',
#    'name_7': 'surname:Wiersma;given-names:L.E.',
#    'name_8': 'surname:van den Berg;given-names:C.W.',
#    'name_9': 'surname:Sol;given-names:W.M.P.J.',
#    'pub-id_pmid': '30506641',
#    'section_type': 'REF',
#    'source': 'Am. J. Transplant.',
#    'type': 'ref',
#    'volume': '19',
#    'year': '2019'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78707,
#   'infons': {'fpage': '226',
#    'lpage': '234',
#    'name_0': 'surname:Zambon;given-names:J.P.',
#    'name_1': 'surname:Ko;given-names:I.K.',
#    'name_2': 'surname:Abolbashari;given-names:M.',
#    'name_3': 'surname:Huling;given-names:J.',
#    'name_4': 'surname:Clouse;given-names:C.',
#    'name_5': 'surname:Kim;given-names:T.H.',
#    'name_6': 'surname:Smith;given-names:C.',
#    'name_7': 'surname:Atala;given-names:A.',
#    'name_8': 'surname:Yoo;given-names:J.J.',
#    'pub-id_pmid': '29883813',
#    'section_type': 'REF',
#    'source': 'Acta Biomater.',
#    'type': 'ref',
#    'volume': '75',
#    'year': '2018'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78708,
#   'infons': {'fpage': '307',
#    'lpage': '318',
#    'name_0': 'surname:Hu;given-names:D.',
#    'name_1': 'surname:Zhang;given-names:D.',
#    'name_10': 'surname:Wei;given-names:G.',
#    'name_2': 'surname:Liu;given-names:B.',
#    'name_3': 'surname:Zhou;given-names:Y.',
#    'name_4': 'surname:Yu;given-names:Y.',
#    'name_5': 'surname:Shen;given-names:L.',
#    'name_6': 'surname:Long;given-names:C.',
#    'name_7': 'surname:Liu;given-names:X.',
#    'name_8': 'surname:Lin;given-names:T.',
#    'name_9': 'surname:He;given-names:D.',
#    'section_type': 'REF',
#    'source': 'Sheng wu gong cheng xue bao = Chin. J. Biotechnol.',
#    'type': 'ref',
#    'volume': '35',
#    'year': '2019'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78709,
#   'infons': {'fpage': '2101',
#    'name_0': 'surname:Lin;given-names:C.H.',
#    'name_1': 'surname:Hsia;given-names:K.',
#    'name_2': 'surname:Ma;given-names:H.',
#    'name_3': 'surname:Lee;given-names:H.',
#    'name_4': 'surname:Lu;given-names:J.H.',
#    'section_type': 'REF',
#    'source': 'Int. J. Mol. Sci.',
#    'type': 'ref',
#    'volume': '19',
#    'year': '2018'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78710,
#   'infons': {'fpage': '1974',
#    'name_0': 'surname:Chaudhari;given-names:A.A.',
#    'name_1': 'surname:Vig;given-names:K.',
#    'name_2': 'surname:Baganizi;given-names:D.R.',
#    'name_3': 'surname:Sahu;given-names:R.',
#    'name_4': 'surname:Dixit;given-names:S.',
#    'name_5': 'surname:Dennis;given-names:V.',
#    'name_6': 'surname:Singh;given-names:S.R.',
#    'name_7': 'surname:Pillai;given-names:S.R.',
#    'section_type': 'REF',
#    'source': 'Int. J. Mol. Sci.',
#    'type': 'ref',
#    'volume': '17',
#    'year': '2016'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78711,
#   'infons': {'name_0': 'surname:Juhasz;given-names:I.',
#    'name_1': 'surname:Kiss;given-names:B.',
#    'name_2': 'surname:Lukacs;given-names:L.',
#    'name_3': 'surname:Erdei;given-names:I.',
#    'name_4': 'surname:Peter;given-names:Z.',
#    'name_5': 'surname:Remenyik;given-names:E.',
#    'section_type': 'REF',
#    'series': 'Dermatology Research and Practice',
#    'type': 'ref',
#    'volume': 'vol. 2010',
#    'year': '2010'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78712,
#   'infons': {'fpage': '837',
#    'lpage': '843',
#    'name_0': 'surname:Mostow;given-names:E.N.',
#    'name_1': 'surname:Haraway;given-names:G.D.',
#    'name_2': 'surname:Dalsing;given-names:M.',
#    'name_3': 'surname:Hodde;given-names:J.P.',
#    'name_4': 'surname:King;given-names:D.',
#    'pub-id_pmid': '15886669',
#    'section_type': 'REF',
#    'source': 'J. Vasc. Surg.',
#    'type': 'ref',
#    'volume': '41',
#    'year': '2005'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78713,
#   'infons': {'name_0': 'surname:Vashi;given-names:A.V.',
#    'name_1': 'surname:White;given-names:J.F.',
#    'name_2': 'surname:Mclean;given-names:K.M.',
#    'name_3': 'surname:Neethling;given-names:W.',
#    'name_4': 'surname:Rhodes;given-names:D.I.',
#    'name_5': 'surname:Ramshaw;given-names:J.',
#    'name_6': 'surname:Werkmeister;given-names:J.A.',
#    'section_type': 'REF',
#    'source': 'J. Biomed. Mater. Res.',
#    'type': 'ref',
#    'volume': '103',
#    'year': '2015'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78714,
#   'infons': {'fpage': '1002',
#    'lpage': '1006',
#    'name_0': 'surname:Simon;given-names:P.',
#    'name_1': 'surname:Kasimir;given-names:M.T.',
#    'name_2': 'surname:Seebacher;given-names:G.',
#    'name_3': 'surname:Weigel;given-names:G.',
#    'name_4': 'surname:Ullrich;given-names:R.',
#    'name_5': 'surname:Salzer-Muhar;given-names:U.',
#    'name_6': 'surname:Rieder;given-names:E.',
#    'name_7': 'surname:Wolner;given-names:E.',
#    'section_type': 'REF',
#    'source': 'Eur. J. Cardio. Thorac. Surg.',
#    'type': 'ref',
#    'volume': '23',
#    'year': '2003'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78715,
#   'infons': {'name_0': 'surname:Yang;given-names:D.',
#    'name_1': 'surname:Xiao;given-names:J.',
#    'name_2': 'surname:Wang;given-names:B.',
#    'name_3': 'surname:Li;given-names:L.',
#    'name_4': 'surname:Kong;given-names:X.',
#    'name_5': 'surname:Liao;given-names:J.',
#    'section_type': 'REF',
#    'source': 'Mater. Sci. Eng. C-Mater. Biol. Appl.',
#    'type': 'ref',
#    'volume': '104',
#    'year': '2019'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78716,
#   'infons': {'fpage': '4803',
#    'lpage': '4820',
#    'name_0': 'surname:Tan;given-names:J.',
#    'name_1': 'surname:Zhang;given-names:Q.-Y.',
#    'name_2': 'surname:Huang;given-names:L.-P.',
#    'name_3': 'surname:Huang;given-names:K.',
#    'name_4': 'surname:Xie;given-names:H.-Q.',
#    'pub-id_pmid': '34018503',
#    'section_type': 'REF',
#    'source': 'Biomater. Sci.',
#    'type': 'ref',
#    'volume': '9',
#    'year': '2021'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78717,
#   'infons': {'name_0': 'surname:Rowley;given-names:A.T.',
#    'name_1': 'surname:Nagalla;given-names:R.R.',
#    'name_2': 'surname:Wang;given-names:S.W.',
#    'name_3': 'surname:Liu;given-names:W.F.',
#    'section_type': 'REF',
#    'source': 'Adv. Healthcare Mater.',
#    'type': 'ref',
#    'volume': '8',
#    'year': '2019'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78718,
#   'infons': {'fpage': '1152',
#    'lpage': '1159',
#    'name_0': 'surname:Dziki;given-names:J.L.',
#    'name_1': 'surname:Huleihel;given-names:L.',
#    'name_2': 'surname:Scarritt;given-names:M.E.',
#    'name_3': 'surname:Badylak;given-names:S.F.',
#    'section_type': 'REF',
#    'source': 'Tissue Eng.',
#    'type': 'ref',
#    'volume': '23',
#    'year': '2017'},
#   'text': '',
#   'sentences': [],
#   'annotations': [],
#   'relations': []},
#  {'offset': 78719,
#   'infons': {'section_type': 'REF', 'type': 'footnote'},
#   'text': 'Peer review under responsibility of KeAi Communications Co., Ltd.',
#   'sentences': [],
#   'annotations': [],
#   'relations': []}]

# %%
# Create a for-loop that iterates throught the text (Create this into its own function that takes the json file, length of dict)
size = len(data['documents'][0]['passages'])
main_content = ''
for i in range(size):
    main_content = main_content + data['documents'][0]['passages'][i]['text'] # note that this also includes the references in the text (title of references)
print(main_content)
# Out:
# Decellularized extracellular matrix scaffolds: Recent trends and emerging strategies in tissue engineeringThe application of scaffolding materials is believed to hold enormous potential for tissue regeneration. Despite the widespread application and rapid advance of several tissue-engineered scaffolds such as natural and synthetic polymer-based scaffolds, they have limited repair capacity due to the difficulties in overcoming the immunogenicity, simulating in-vivo microenvironment, and performing mechanical or biochemical properties similar to native organs/tissues. Fortunately, the emergence of decellularized extracellular matrix (dECM) scaffolds provides an attractive way to overcome these hurdles, which mimic an optimal non-immune environment with native three-dimensional structures and various bioactive components. The consequent cell-seeded construct based on dECM scaffolds, especially stem cell-recellularized construct, is considered an ideal choice for regenerating functional organs/tissues. Herein, we review recent developments in dECM scaffolds and put forward perspectives accordingly, with particular focus on the concept and fabrication of decellularized scaffolds, as well as the application of decellularized scaffolds and their combinations with stem cells (recellularized scaffolds) in tissue engineering, including skin, bone, nerve, heart, along with lung, liver and kidney.Graphical abstractHighlightdECM scaffolds for tissue regeneration are primarily introduced according to the development and fabrication of decellularized scaffolds, as well as the application of dECM scaffolds and their constructs combined with stem cells in various tissue engineering.Limitations, challenges, and perspectives of dECM for accelerating development of tissue regeneration are discussed, respectively.Introduction of decellularized extracellular matrix scaffoldsList of main protein components in dECM.Table 1	 	Protein	Distributions	Function	Reference	 	Collagen	The skeletal systems and most soft tissues	Provide tensile strength, connect the framework of tissue/organ, affect cell types disposition		 	Elastin	Most soft tissues, such as vasculature and muscle	Provide elasticity, adjust mechanical properties, increase hemocompatibility		 	Fibronectin	Most organs/tissues	Regulate cell behavior and function, guide branching morphogenesis in the development of complicated structures		 	Laminin	Cartilage, muscle	Promote cell adhesion and migration, provide bioactive sites for cross-linking		 	Matricellular Proteins	Vasculature	Contain binding sites for ECM structural proteins and cell surface receptors, and modulate activities of specific growth factors		 	Along with the rapid development of tissue engineering in the past decades, biological scaffolds have attracted significant interest in this field due to their great biocompatibility and bioactivity, and moderate mechanical performances for supporting cells. Among various types of scaffolds, decellularized extracellular matrix (dECM) scaffolds, which refer to biomaterials formed by human or animal organs/tissues with the removal of immunogenic cellular components via decellularized technologies, are under the spotlight. dECM scaffolds mainly consist of extracellular matrix (ECM), which is a three-dimensional (3D) framework containing extracellular macromolecules such as collagen, elastin, fibronectin, laminin, and matricellular proteins, as listed in Table 1. Meanwhile, the physicochemical signals and biological performance of dECM can be remained after decellularization, which provides a substrate for mechanical supporting and a biological 3D carrier for subsequent cell seeding. Therefore, such recellularized dECM can be implanted into patients for tissue engineering, including restoration of damaged organs, regeneration of endogenous tissues, and replacement of missing organs.Timeline of decellularized extracellular matrix (dECM) scaffolds. Crude decellularization technique emerged in 1948 ...

# %%
title = data['documents'][0]['passages'][0]['text']

pmid = data['documents'][0]['passages'][0]['infons']['article-id_pmid']

content_list = [pmid, title, main_content]

# %%
# Dataframe to store retrieved data
studies_table = pd.DataFrame(columns=['id', 'title', 'body_content'])
studies_table
# Out:
# Empty DataFrame
# Columns: [id, title, body_content]
# Index: []

# %%
studies_table.loc[len(studies_table)] = content_list
pd.set_option('display.max_colwidth', 1)

# %%
studies_table
studies_table['body_content'].replace('\t', '') # some text has \t so it needs to be removed (check a few of the text to see what they contain)
# Out:
# 0    Decellularized extracellular matrix scaffolds: Recent trends and emerging strategies in tissue engineeringThe application of scaffolding materials is believed to hold enormous potential for tissue regeneration. Despite the widespread application and rapid advance of several tissue-engineered scaffolds such as natural and synthetic polymer-based scaffolds, they have limited repair capacity due to the difficulties in overcoming the immunogenicity, simulating in-vivo microenvironment, and performing mechanical or biochemical properties similar to native organs/tissues. Fortunately, the emergence of decellularized extracellular matrix (dECM) scaffolds provides an attractive way to overcome these hurdles, which mimic an optimal non-immune environment with native three-dimensional structures and various bioactive components. The consequent cell-seeded construct based on dECM scaffolds, especially stem cell-recellularized construct, is considered an ideal choice for regenerating functional organs/tissues. Herein, we review recent developments in dECM scaffolds and put forward perspectives accordingly, with particular focus on the concept and fabrication of decellularized scaffolds, as well as the application of decellularized scaffolds and their combinations with stem cells (recellularized scaffolds) in tissue engineering, including skin, bone, nerve, heart, along with lung, liver and kidney.Graphical abstractHighlightdECM scaffolds for tissue regeneration are primarily introduced according to the development and fabrication of decellularized scaffolds, as well as the application of dECM scaffolds and their constructs combined with stem cells in various tissue engineering.Limitations, challenges, and perspectives of dECM for accelerating development of tissue regeneration are discussed, respectively.Introduction of decellularized extracellular matrix scaffoldsList of main protein components in dECM.Table 1\t \tProtein\tDistributions\tFunction\tReference\t \tCollagen\tThe skeletal systems and most soft tissues\tProvide tensile strength, connect the framework of tissue/organ, affect cell types disposition\t\t \tElastin\tMost soft tissues, such as vasculature and muscle\tProvide elasticity, adjust mechanical properties, increase hemocompatibility\t\t \tFibronectin\tMost organs/tissues\tRegulate cell behavior and function, guide branching morphogenesis in the development of complicated structures\t\t \tLaminin\tCartilage, muscle\tPromote cell adhesion and migration, provide bioactive sites for cross-linking\t\t \tMatricellular Proteins\tVasculature\tContain binding sites for ECM structural proteins and cell surface receptors, and modulate activities of specific growth factors\t\t \tAlong with the rapid development of tissue engineering in the past decades, biological scaffolds have attracted significant interest in this field due to their great biocompatibility and bioactivity, and moderate mechanical performances for supporting cells. Among various types of scaffolds, decellularized extracellular matrix (dECM) scaffolds, which refer to biomaterials formed by human or animal organs/tissues with the removal of immunogenic cellular components via decellularized technologies, are under the spotlight. dECM scaffolds mainly consist of extracellular matrix (ECM), which is a three-dimensional (3D) framework containing extracellular macromolecules such as collagen, elastin, fibronectin, laminin, and matricellular proteins, as listed in Table 1. Meanwhile, the physicochemical signals and biological performance of dECM can be remained after decellularization, which provides a substrate for mechanical supporting and a biological 3D carrier for subsequent cell seeding. Therefore, such recellularized dECM can be implanted into patients for tissue engineering, including restoration of damaged organs, regeneration of endogenous tissues, and replacement of missing organs.Timeline of decellularized extracellular matrix (dECM) scaffolds. Crude decell ...
# Name: body_content, dtype: object

# %%
studiesIdList[:2]
# Out:
# ['34901526', '31075518']
